# %%
import pandas as pd

# %%
df = pd.read_csv('./Downloads/leben.csv')
df.columns = ['Artist', 'Album', 'Track', 'Date']
df.head()
# Out:
#      Artist Album         Track               Date
# 0  Bon Iver    ii  U (Man Like)  19 Aug 2019 21:33
# 1  Bon Iver    ii    Holyfields  19 Aug 2019 21:29
# 2  Bon Iver    ii            We  19 Aug 2019 04:00
# 3  Bon Iver    ii           iMi  19 Aug 2019 03:57
# 4  Bon Iver    ii            Yi  19 Aug 2019 03:56

# %%
df.describe()
# Out:
#              Artist  Album  Track               Date
# count         39516  38874  39516              39516
# unique         5816   9767  20113              38595
# top     Max Richter  Sleep  Intro  01 Jan 1970 00:03
# freq            720    669     89                 60

# %%
artist_count = df.groupby(by='Artist')
artist_count.head()
# Out:
#                                     Artist  \
# 0                                 Bon Iver
# 1                                 Bon Iver
# 2                                 Bon Iver
# 3                                 Bon Iver
# 4                                 Bon Iver
# 5                             The Internet
# 6                             The Internet
# 7                             The Internet
# 8                             The Internet
# 9                            LINGUA IGNOTA
# 10                           LINGUA IGNOTA
# 11                  White Noise Baby Sleep
# 12                         Matthias Stuski
# 13                       Noise for Healing
# 14                                Granular
# 15                                 Grouper
# 16                   Oneohtrix Point Never
# 17                              Panda Bear
# 18                               Avey Tare
# 19                           Susumu Yokota
# 20                                 Grouper
# ...
